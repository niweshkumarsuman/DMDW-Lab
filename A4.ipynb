# %% [markdown]
# <a href="https://colab.research.google.com/github/niweshkumarsuman/DMDW-Lab/blob/main/A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

Rn=[]
M=[]
n=int(input("Enter the Number of Students: "))
for i in range(n):
  Rn.append(input("Enter Roll No."))
  M.append(int(input("Enter Mark ")))
print(Rn)
print(M)
plt.bar(Rn,M)
# Out:
# Enter the Number of Students: 5
# Enter Roll No.19CSE026
# Enter Mark 90
# Enter Roll No.19CSE047
# Enter Mark 88
# Enter Roll No.19CSE045
# Enter Mark 65
# Enter Roll No.19CSE032
# Enter Mark 78
# Enter Roll No.19CSE025
# Enter Mark 88
# ['19CSE026', '19CSE047', '19CSE045', '19CSE032', '19CSE025']
# [90, 88, 65, 78, 88]
# <BarContainer object of 5 artists>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-e2353c19-473a-4457-9ce5-44acb724c60a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e2353c19-473a-4457-9ce5-44acb724c60a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Iris.csv to Iris.csv

# %%
df=pd.read_csv("Iris.csv")
print(df.head())
df.hist()
print(plt.show())
#df.scatter()
plt.show()
df.plot()
plt.show()
df.boxplot()
plt.show()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# None

# %%
#4c
import numpy as np
import matplotlib.pyplot as plt
pre= np.array([19,6,11,9])
post=np.array([15,11,9,8])
labels=['Survey'+x for x in list('ABCD')]
# the plot - left then right
fig, ax = plt.subplots(figsize=(8,3.5))
width=0.4
xlocs=np.arange(len(pre))
ax.bar(xlocs-width,pre,width,color='green',label='True')
ax.bar(xlocs,post,width,color='#1f10ed',label='False')
#labels, and title,then save
ax.set_xticks(ticks=range(len(pre)))
ax.set_xticklabels(labels)
ax.legend(loc='best')
ax.set_ylabel('Count')
fig.suptitle('Sample Chart')
fig.savefig('azy.png',dpi=125)
