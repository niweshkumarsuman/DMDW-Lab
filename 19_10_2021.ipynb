# %% [markdown]
# <a href="https://colab.research.google.com/github/niweshkumarsuman/DMDW-Lab/blob/main/19_10_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(5)
y=(20,35,30,35,27)
plt.plot(x,y)
plt.show()
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(0,20,100)
#print(x)
y=np.sin(x)
#print(y)
plt.plot(x,y,label='Sample Label')
plt.xlabel(" x axis sample")
plt.ylabel(" y axis sample")
plt.title("Sample Plot Title")
plt.show()
plt.savefig('new_chart.jpg')
plt.show()

# %%
x=np.linspace(0,20,100)
y=np.sin(x)
fig=plt.figure(figsize=(8,4))
ax=fig.add_subplot(1,1,1)
#ax.plot(x,y)
ax.plot(x,y,'y-',linewidth=2,label='Sample label')

# %%
fig, ax=plt.subplots()
fig,(ax1,ax2,ax3)=plt.subplots(nrows=3,ncols=1,sharex=True,figsize=(8,4))

# %%
x1=np.linspace(0,100,20)
x2=np.linspace(0,100,20)
x3=np.linspace(0,100,20)
y1=np.sin(x1)
y2=np.cos(x2)
y3=np.tan(x3)
fig, ax=plt.subplots(figsize=(8,4))
ax.plot(x1,y1,label='sin')
ax.plot(x2,y2,label='cos')
ax.plot(x3,y3,label='tan')
ax.legend(loc='best',prop={'size':'large'})

# %%
fig,(ax1,ax2,ax3)=plt.subplots(nrows=3,ncols=1,sharex=False,sharey=False,figsize=(8,4))
ax1.plot(x1,y1,label)
